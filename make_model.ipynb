# %%
import numpy as np
import keras
from keras.layers import Dense, Input, Conv2D, MaxPooling2D, Dropout, Flatten, Concatenate
from keras.models import Sequential, Model, load_model
# Out:
# Using TensorFlow backend.

# %%
train_input = np.loadtxt('input.csv', delimiter=',')
train_label = np.loadtxt('label.csv', delimiter=',')
train_input = np.reshape(train_input, (-1, 480,480,1))

# %%
input_layer = Input(shape=(480,480,1))
########################################################################################################################################
conv_layer_1_conv_1 = Conv2D(2, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu')(input_layer)
conv_layer_1_maxpooling = MaxPooling2D(pool_size=(3,3), strides=(3,3))(conv_layer_1_conv_1)
conv_layer_1_dropout = Dropout(0.25)(conv_layer_1_maxpooling)
########################################################################################################################################
conv_layer_2_conv_1 = Conv2D(4, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu')(conv_layer_1_dropout)

conv_layer_2_conv_2 = Conv2D(4, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu')(conv_layer_1_dropout)
conv_layer_2_conv_3 = Conv2D(4, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu')(conv_layer_2_conv_2)

conv_layer_2_conv_4 = Conv2D(4, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu')(conv_layer_1_dropout)
conv_layer_2_conv_5 = Conv2D(4, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu')(conv_layer_2_conv_4)
conv_layer_2_conv_6 = Conv2D(4, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu')(conv_layer_2_conv_5)

conv_layer_2_concatenate = Concatenate(axis=-1)([conv_layer_2_conv_1, conv_layer_2_conv_3, conv_layer_2_conv_6])
conv_layer_2_maxpooling = MaxPooling2D(pool_size=(3,3), strides=(3,3))(conv_layer_2_concatenate)
conv_layer_2_dropout = Dropout(0.25)(conv_layer_2_maxpooling)
########################################################################################################################################
conv_layer_3_conv_1 = Conv2D(24, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu')(conv_layer_2_dropout)
conv_layer_3_maxpooling = MaxPooling2D(pool_size=(3,3), strides=(3,3))(conv_layer_3_conv_1)
conv_layer_3_dropout = Dropout(0.25)(conv_layer_3_maxpooling)
########################################################################################################################################
conv_layer_4_conv_1 = Conv2D(48, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu')(conv_layer_3_dropout)

conv_layer_4_conv_2 = Conv2D(48, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu')(conv_layer_3_dropout)
conv_layer_4_conv_3 = Conv2D(48, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu')(conv_layer_4_conv_2)

conv_layer_4_conv_4 = Conv2D(48, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu')(conv_layer_3_dropout)
conv_layer_4_conv_5 = Conv2D(48, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu')(conv_layer_4_conv_4)
conv_layer_4_conv_6 = Conv2D(48, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu')(conv_layer_4_conv_5)

conv_layer_4_concatenate = Concatenate(axis=-1)([conv_layer_4_conv_1, conv_layer_4_conv_3, conv_layer_4_conv_6])
conv_layer_4_maxpooling = MaxPooling2D(pool_size=(3,3), strides=(3,3))(conv_layer_4_concatenate)
conv_layer_4_dropout = Dropout(0.25)(conv_layer_4_maxpooling)
#########################################################################################################################################
conv_layer_5_conv_1 = Conv2D(288, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu')(conv_layer_4_dropout)
conv_layer_5_maxpooling = MaxPooling2D(pool_size=(3,3), strides=(3,3))(conv_layer_5_conv_1)
conv_layer_5_dropout = Dropout(0.25)(conv_layer_5_maxpooling)
#########################################################################################################################################
flatten = Flatten()(conv_layer_5_dropout)

dense_1 = Dense(100, activation='relu')(flatten)
dropout_1 = Dropout(0.5)(dense_1)

dense_2 = Dense(10, activation='relu')(dropout_1)
dropout_2 = Dropout(0.5)(dense_2)

output_layer = Dense(2, activation='softmax')(dropout_2)

model = Model(inputs = input_layer, outputs = output_layer)

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From D:\anaconda\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From D:\anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 480, 480, 1)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 480, 480, 2)  20          input_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 160, 160, 2)  0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 160, 160, 2)  0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 160, 160, 4)  76          dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 160, 160, 4)  76          dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 160, 160, 4)  148         conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 160, 160, 4)  76          dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 160, 160, 4)  148         conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 160, 160, 4)  148         conv2d_6[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 160, 160, 12) 0           conv2d_2[0][0]
#                                                                  conv2d_4[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 53, 53, 12)   0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 53, 53, 12)   0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 53, 53, 24)   2616        dropout_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 17, 17, 24)   0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 17, 17, 24)   0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 17, 17, 48)   10416       dropout_3[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 17, 17, 48)   10416       dropout_3[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 17, 17, 48)   20784       conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 17, 17, 48)   10416       dropout_3[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 17, 17, 48)   20784       conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 17, 17, 48)   20784       conv2d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 17, 17, 144)  0           conv2d_9[0][0]
#                                                                  conv2d_11[0][0]
#                                                                  conv2d_14[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 5, 5, 144)    0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 5, 5, 144)    0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 5, 5, 288)    373536      dropout_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 1, 1, 288)    0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 1, 1, 288)    0           max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 288)          0           dropout_5[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 100)          28900       flatten_1[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 100)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 10)           1010        dropout_6[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 10)           0           dense_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 2)            22          dropout_7[0][0]
# ==================================================================================================
# Total params: 500,376
# Trainable params: 500,376
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.load_weights('weights.h5')

# %%
model.fit(train_input, train_label, 
         epochs=100,
         batch_size=10,
         shuffle=True)
# Out:
# Epoch 1/100
# 350/350 [==============================] - 1s 4ms/step - loss: 7.9483 - accuracy: 0.5143
# Epoch 2/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.7970 - accuracy: 0.4829
# Epoch 3/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.7496 - accuracy: 0.5171
# Epoch 4/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.7198 - accuracy: 0.5400
# Epoch 5/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.7088 - accuracy: 0.5543
# Epoch 6/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.6053 - accuracy: 0.6486
# Epoch 7/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.4779 - accuracy: 0.7914
# Epoch 8/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.3157 - accuracy: 0.8971
# Epoch 9/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.2067 - accuracy: 0.9286
# Epoch 10/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.2325 - accuracy: 0.9200
# Epoch 11/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.2004 - accuracy: 0.9171
# Epoch 12/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0671 - accuracy: 0.9857
# Epoch 13/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0659 - accuracy: 0.9857
# Epoch 14/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0590 - accuracy: 0.9829
# Epoch 15/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0402 - accuracy: 0.9914
# Epoch 16/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0515 - accuracy: 0.9857
# Epoch 17/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0357 - accuracy: 0.9971
# Epoch 18/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0348 - accuracy: 0.9971
# Epoch 19/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0309 - accuracy: 0.9943
# Epoch 20/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0863 - accuracy: 0.9714
# Epoch 21/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0291 - accuracy: 0.9971
# Epoch 22/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0187 - accuracy: 0.9971
# Epoch 23/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0542 - accuracy: 0.9943
# Epoch 24/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0281 - accuracy: 0.9971
# Epoch 25/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0308 - accuracy: 0.9943
# Epoch 26/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0228 - accuracy: 1.0000
# Epoch 27/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0306 - accuracy: 0.9971
# Epoch 28/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0264 - accuracy: 0.9971
# Epoch 29/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0253 - accuracy: 0.9943
# Epoch 30/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0315 - accuracy: 0.9914
# Epoch 31/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0295 - accuracy: 0.9943
# Epoch 32/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.3091 - accuracy: 0.9343
# Epoch 33/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0575 - accuracy: 0.9857
# Epoch 34/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0426 - accuracy: 0.9914
# Epoch 35/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0212 - accuracy: 1.0000
# Epoch 36/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0196 - accuracy: 0.9971
# Epoch 37/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0165 - accuracy: 0.9971
# Epoch 38/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0164 - accuracy: 1.0000
# Epoch 39/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0250 - accuracy: 0.9971
# Epoch 40/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0218 - accuracy: 0.9971
# Epoch 41/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0268 - accuracy: 0.9943
# Epoch 42/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0259 - accuracy: 0.9943
# Epoch 43/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0180 - accuracy: 1.0000
# Epoch 44/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0196 - accuracy: 0.9971
# Epoch 45/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0186 - accuracy: 0.9971
# Epoch 46/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0178 - accuracy: 1.0000
# Epoch 47/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0259 - accuracy: 0.9943
# Epoch 48/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0137 - accuracy: 1.0000
# Epoch 49/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0192 - accuracy: 0.9971
# Epoch 50/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0232 - accuracy: 0.9943
# Epoch 51/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0185 - accuracy: 0.9971
# Epoch 52/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0188 - accuracy: 1.0000
# Epoch 53/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0422 - accuracy: 0.9886
# Epoch 54/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0158 - accuracy: 0.9971
# Epoch 55/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.1475 - accuracy: 0.9771
# Epoch 56/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0478 - accuracy: 0.9886
# Epoch 57/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0178 - accuracy: 1.0000
# Epoch 58/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0238 - accuracy: 0.9971
# Epoch 59/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0234 - accuracy: 0.9943
# Epoch 60/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0407 - accuracy: 0.9857
# Epoch 61/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0183 - accuracy: 0.9971
# Epoch 62/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0129 - accuracy: 1.0000
# Epoch 63/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0185 - accuracy: 0.9971
# Epoch 64/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0243 - accuracy: 0.9943
# Epoch 65/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0098 - accuracy: 1.0000
# Epoch 66/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0116 - accuracy: 1.0000
# Epoch 67/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0125 - accuracy: 1.0000
# Epoch 68/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0238 - accuracy: 0.9943
# Epoch 69/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0277 - accuracy: 0.9943
# Epoch 70/100
# 350/350 [==============================] - 1s 3ms/step - loss: 0.0257 - accuracy: 0.9943
# Epoch 71/100
# 350/350 [==============================] - 1s 3ms/step - loss: 0.0114 - accuracy: 1.0000
# Epoch 72/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0173 - accuracy: 0.9971
# Epoch 73/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0103 - accuracy: 1.0000
# Epoch 74/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0121 - accuracy: 1.0000
# Epoch 75/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0149 - accuracy: 0.9971
# Epoch 76/100
# 350/350 [==============================] - 1s 3ms/step - loss: 0.0166 - accuracy: 0.9971
# Epoch 77/100
# 350/350 [==============================] - 1s 3ms/step - loss: 0.0085 - accuracy: 1.0000
# Epoch 78/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0218 - accuracy: 0.9943
# Epoch 79/100
# 350/350 [==============================] - 1s 3ms/step - loss: 0.0125 - accuracy: 1.0000
# Epoch 80/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0251 - accuracy: 0.9914
# Epoch 81/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0135 - accuracy: 0.9971
# Epoch 82/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0158 - accuracy: 0.9971
# Epoch 83/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0162 - accuracy: 0.9971
# Epoch 84/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0128 - accuracy: 1.0000
# Epoch 85/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0188 - accuracy: 0.9943
# Epoch 86/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0128 - accuracy: 0.9971
# Epoch 87/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0136 - accuracy: 0.9971
# Epoch 88/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0080 - accuracy: 1.0000
# Epoch 89/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0062 - accuracy: 1.0000
# Epoch 90/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0145 - accuracy: 0.9971
# Epoch 91/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0078 - accuracy: 1.0000
# Epoch 92/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0086 - accuracy: 1.0000
# Epoch 93/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0083 - accuracy: 1.0000
# Epoch 94/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0206 - accuracy: 0.9943
# Epoch 95/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0079 - accuracy: 1.0000
# Epoch 96/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0243 - accuracy: 0.9914
# Epoch 97/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0165 - accuracy: 0.9971
# Epoch 98/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0193 - accuracy: 0.9943
# Epoch 99/100
# 350/350 [==============================] - 1s 4ms/step - loss: 0.0144 - accuracy: 1.0000
# Epoch 100/100
# 350/350 [==============================] - 1s 3ms/step - loss: 0.0183 - accuracy: 0.9943

# %%
model.save('model/model_2.h5')
