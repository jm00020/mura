# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
path = 'data/0/w225_0_0001.bmp'
path2 = 'data/1/w255_1_0001.bmp'

# %%
img = np.array(Image.open(path))
img2 = np.array(Image.open(path2))

# %%
plt.imshow(img)

# %%
plt.imshow(img2)

# %%
img = (255-img)
img2 = (255-img2)

# %%
plt.imshow(img)

# %%
plt.imshow(img2)

# %%
print(img1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-63-4e889359c9fe> in <module>
# ----> 1 print(img1)
#
# NameError: name 'img1' is not defined
